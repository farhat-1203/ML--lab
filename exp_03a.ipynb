# %%
# NAME: Farhat Momin
# ROLL NO.: 23
# UIN: 221P019

# %%
# AIM: Implement a Simple Linear model for Addition of Two Numbers
# using Machine Learning (With GUI).

import pandas as pd
df = pd.read_csv("./add.csv")
df.head()
# Out:
#       x     y   sum
# 0   1.0   1.0   2.0
# 1   4.0   4.0   8.0
# 2   6.0   6.0  12.0
# 3  10.0  10.0  20.0
# 4  30.0  30.0  60.0

# %%
import matplotlib.pyplot as plt
plt.scatter(df["x"],df["sum"])
plt.title(" X Versus Sum By Seemin Khan")
# Out:
# Text(0.5, 1.0, ' X Versus Sum By Seemin Khan')

# %%
import matplotlib.pyplot as plt
plt.scatter(df["y"],df["sum"])
plt.title(" Y Versus Sum By Seemin Khan")
# Out:
# Text(0.5, 1.0, ' Y Versus Sum By Seemin Khan')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df[["x", "y"]], df["sum"], test_size=0.2, random_state=42)                                                                                     
reg = LinearRegression()
reg.fit(X_train,Y_train)
Y_predict = reg.predict(X_test)
result = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_predict})
result
# Out:
#     Actual  Predicted
# 0      2.0        2.0
# 13   112.9      112.9
# 8     68.0       68.0
# 1      8.0        8.0
# 15   900.0      900.0

# %%
import tkinter as tk
import pandas as pd
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

root = tk.Tk()
root.title("Add two numbers using LR")
root.geometry('800x400')
def predict_sum():
    try:
        x = float(entry_x.get())
        y = float(entry_y.get())
        input_df = pd.DataFrame({
            'x': [x],
            'y': [y]
        })
        sum_prediction = reg.predict(input_df)
        label_prediction.config(text=f"Predicted Sum: {sum_prediction[0]:.2f}")
    except ValueError:
        label_prediction.config(text="Please enter valid numbers.")
# UI Components
label_entry = tk.Label(root, text="Enter X and Y values:")
label_entry.pack(pady=10)
entry_x = tk.Entry(root, width=10)
entry_x.pack()
entry_y = tk.Entry(root, width=10)
entry_y.pack()
button_predict = tk.Button(root, text="Predict sum", command=predict_sum)
button_predict.pack(pady=10)
label_prediction = tk.Label(root, text="")
label_prediction.pack(pady=10)
root.mainloop()
